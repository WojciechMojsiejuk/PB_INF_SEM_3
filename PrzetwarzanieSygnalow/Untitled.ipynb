# %% [markdown]
# # Zadanie 1.3
# Sporządź wykres funkcji $$\begin{align*}
# y = x^2 + 5
# \end{align*}$$ w dziedzinie od -10 do 10.

# %%
from pylab import *
x = np.linspace(-10, 10)
y = x **2 + 5
figure()
plot(x, y, 'r')
xlabel('x')
h = ylabel('y')
h.set_rotation(0)
title(r'Wykres funkcji $y=x^2+5$')
show()
